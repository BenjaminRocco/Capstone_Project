# %%
# !pip install --upgrade tensorflow
#then restart and clear all cells DO NOT FACTORY RESET

# %%
import tensorflow as tf
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,\
    Embedding, Lambda
from tensorflow.keras.preprocessing.text import Tokenizer
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import sparse_categorical_accuracy
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.metrics import Accuracy
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

import re
import nltk
import matplotlib.pyplot as plt
from keras.preprocessing import text
from keras.preprocessing.sequence import skipgrams

# %%
df = pd.read_csv('/kaggle/input/dfnew-with-section-names/dfnew_with_section_names.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                           Document Category
# 0           0  see latest charts maps coronavirus cases death...  Opinion
# 1           1  biggest increases come groups past far less li...  Opinion
# 2           2  miguel cardona education secretary said reopen...  Opinion
# 3           3  mohamed morsi egypt first democratically elect...   Sports
# 4           4  see full results maps district columbia electi...   Sports

# %%
df = df.drop(columns='Unnamed: 0')

# %%
df['Category'] = df['Category'].str.lower()

# %%
df.head()
# Out:
#                                             Document Category
# 0  see latest charts maps coronavirus cases death...  opinion
# 1  biggest increases come groups past far less li...  opinion
# 2  miguel cardona education secretary said reopen...  opinion
# 3  mohamed morsi egypt first democratically elect...   sports
# 4  see full results maps district columbia electi...   sports

# %%
wpt = nltk.WordPunctTokenizer()
stop_words = nltk.corpus.stopwords.words('english')

def normalize_document(doc):
    # lower case and remove special characters\whitespaces
    doc = re.sub(r'[^a-zA-Z\s]', '', doc, re.I|re.A)
    doc = doc.lower()
    doc = doc.strip()
    # tokenize document
    tokens = wpt.tokenize(doc)
    # filter stopwords out of document
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # re-create document from filtered tokens
    doc = ' '.join(filtered_tokens)
    return doc

normalize_corpus = np.vectorize(normalize_document)

# %%
sampled_test = df.sample(n=1000, random_state=42)

# %%
corpus = sampled_test['Document'].tolist()

# %%
norm_corpus = normalize_corpus(corpus)
norm_corpus
# Out:
# array(['nan california primary election results sixth house district',
#        'gunman fired shots united states embassy bosnian capital sarajevo friday shots fired u embassy bosnia',
#        'demonstrations spread dozens iranian cities set miscalculations long simmering internal power struggle hard liners reformers tapped iranians ire protest targets',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations butler county kentucky track covid butler county kentucky',
#        'productivity growth lags living standards american workers stifling pay raises also curbing economic growth',
#        'see full results maps north carolina elections north carolina election results',
#        'movement underway slow obsolescence electronic gear smartphone built last',
#        'brazil president denial trump lost bolsonaro get',
#        'jordanian authorities appealed united states wednesday surveillance airplanes intelligence help secure border favored arms smugglers jordan asks assistance securing syrian border',
#        'relentless mass shootings million dead covid much value single life arrow america heart',
#        'endless congressional investigations serve crucial purpose republican politicians strategists fundraisers r scandal go away',
#        'virus feasted compromised body difficult independence day',
#        'see latest charts maps coronavirus cases deaths hospitalizations arkadelphia area clark county arkansas covid case risk tracker',
#        'crude west texas shale fields increasingly making way abroad pipeline system expanded take market corpus christi oil exports illegal decades fuel texas port boom',
#        'tea party nudged republicans right congress falls short comes recruiting good challengers take incumbents tea party aims incumbents falls short',
#        'united states accept weaker banking regulation return free trade agreement european union economist writes perils free trade pact europe',
#        'two years george floyd murder street art created summer uprising hope inspired fading away memory george floyd literally fading across america',
#        'requirement test covid flying united states hated many travelers u travel industry government shows sign getting rid going testing requirement travel',
#        'see full results maps washington election washington election results second congressional district',
#        'inside complicated logistics sending american jews cemeteries holy land wished buried israel died eve war',
#        'denial racial inequity history white delusion',
#        'contrast vibe silicon valley obstruction washington quite telling start america best hope',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations mahnomen county minnesota track covid mahnomen county minnesota',
#        'see latest charts maps coronavirus cases deaths hospitalizations claiborne parish louisiana claiborne parish louisiana covid case risk tracker',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations eureka county nevada track covid eureka county nevada',
#        'see full results maps nevada election nevada election results second congressional district',
#        'service six term republican senator indiana died last month many trappings state funeral richard lugar remembered true american statesman',
#        'legislators agreed normalize ties first time decades move impose sanctions defies president obama lobbied mixing issues trade deal russia u plans sanctions human rights abuses',
#        'dream act would given legal status chance citizenship people like isabel castillo given trying get passed dream act advocate turns failure hope',
#        'way really address climate crisis politics policymakers legislation worrying carbon footprint exactly big oil wants',
#        'regulators united states britain switzerland seem moving toward tougher rules banks much continental europe still weaknesses addressed banks proliferate rules',
#        'deutsche bank agreed settle federal energy regulatory commission charges bank manipulated california energy markets bank pay million fine surrender profit deutsche bank agrees settle energy trading inquiry',
#        'clearest statement merger netflix nearly two months agreed pay comcast direct connection cable operator internet backbone netflix says opposes comcast merger bid',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations liberty county georgia track covid liberty county georgia',
#        'country released new details large military procession heart beijing commemorate th anniversary end war preparations proceed china world war ii parade',
#        'american lost men meter backstroke news conference mentioned russia problems doping ryan murphy casts doubt whether russian swimmer beat cleanly',
#        'white mortality rates tell us crisis working class dying whites',
#        'food manufacturers groping strategies encourage donations food banks composting substantial portion food thrown away still fully edible cosmetic blemishes overstocking war food waste',
#        'federal regulators identified single cause hour extreme volatility treasuries market last fall treasury flash rally report released',
#        'see full results maps louisiana election louisiana election results first congressional district',
#        'see latest charts maps coronavirus cases deaths hospitalizations east carroll parish louisiana east carroll parish louisiana covid case risk tracker',
#        'count reflects slowest population growth since also offers glimpse shifting centers population power united states know census data',
#        'united states defeated colombia sweden topped north korea advance quarterfinals women world cup germany u women advance quarterfinals',
#        'aboard u john c stennis preparing bombs day work u stennis assembly line',
#        'despite strong start yielded four blockbuster transactions one week first half slowest first six months mergers four years merger activity first half',
#        'terry babcock lumish economics professor united states military academy teaching west point magic west point',
#        'imprisonment andrew brunson prompted sanctions trump administration turkish foreign minister said harsh tactics would work pompeo warns turkey detained u pastor clock run',
#        'despite promising report week international energy agency nation would still need concerned foreign markets oil prices set globally energy independence united states pop cork yet',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations storey county nevada track covid storey county nevada',
#        'electronic privacy information center says united states lags confronting cyber privacy threat surveillance china implications americans',
#        'demands unity actually tear us apart biden wasting precious time fighting america soul',
#        'arriving white house wednesday pope francis spoke topics including immigration environment pope full remarks white house',
#        'president attempt walk back comments little mollify intelligence officials especially came mr putin offer aid mueller investigation u intelligence community reacts fury trump rebuke',
#        'vaccine deliveries u states contingent food drug administration authorizing pediatric doses step could occur soon next week white house outlines coronavirus vaccine plan children',
#        'argue impeachment divisive fine unity',
#        'new information comes congress debates immigration overhaul could include pathway legal status citizenship number illegal immigrants u may rise estimates say',
#        'readers discuss two recent supreme court actions religious exemptions contraception coverage',
#        'holiday season exchanges like one organized food strangers give edible gifts receive sense connection magic food gift swap',
#        'homicide rates large cities percent average last year another percent beginning year according criminologists homicides rising cities brace violent summer',
#        'legal definition bias motivated crimes varies acts bringing vastly different punishments depending state occur spread hate crimes lawmakers seeking harsher penalties',
#        'bloodshed continues make difference armed holidays',
#        'luke somers journalist pierre korkie teacher held al qaeda affiliate yemen died raid united states commandos saturday officials said hostages killed yemen u rescue effort fails',
#        'photos armenia india united states kenya june pictures day',
#        'congress authority limit president reckless endangerment economy stop trump trade war madness',
#        'see full results maps new york election new york election results th congressional district',
#        'whether someone owns gun powerful predictor person political party gender sexual orientation many demographic traits party identity gun cabinet',
#        'today poll taxes literacy tests right vote fragile ever voting rights act',
#        'estimates exit polls offer initial indication groups voted election night wisconsin voter surveys different groups voted',
#        'see full results maps california election california election results th congressional district',
#        'see latest charts maps coronavirus cases deaths hospitalizations bourbon county kansas bourbon county kansas covid case risk tracker',
#        'descendants robert e lee others whose statues coming confronting moment reassessment history personal way toppled statue great great great grandfather',
#        'obscure tilapia americans favorite farmed fish critics point environmental nutritional drawbacks another side tilapia perfect factory fish',
#        'narrative around sonic attack american embassy cuba fits troubling pattern trump mysterious sounds scary illnesses political tools',
#        'see full results maps maine election maine election results second congressional district',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations forrest county mississippi track covid forrest county mississippi',
#        'former asylum officer says remain mexico policies undermining asylum racist illegal quit job carrying trump immigration policies',
#        'massive gatherings racial justice across country world achieved scale level momentum seen decades protests flare fade movement already seems different',
#        'patrick reed setting tone sinking clutch putts united states lead going sunday hazeltine national golf club u stifles european surge ryder cup retake momentum',
#        'see full results maps georgia election georgia election results th congressional district',
#        'ukraine refusal bend knee vladimir putin reminded west life liberalism worth fighting enemies liberalism showing us really means',
#        'europe experienced hottest summer ever fifth hottest year record worldwide last years hottest record',
#        'shift c c employers withdrew mask policies workers felt protecting unvaccinated customers many workers change mask policy nightmare',
#        'knows cocky fixer humbled could find star witness hearings impeachment th president michael cohen bring trump',
#        'see latest charts maps coronavirus cases deaths hospitalizations johnson county arkansas johnson county arkansas covid case risk tracker',
#        'new survey merrill lynch global wealth management wealthy americans cited rising health care costs top financial concern rising health costs top financial concern affluent',
#        'republican leadership hold fractious lawmakers together effectively exert new power today politics',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations cherokee county south carolina track covid cherokee county south carolina',
#        'recent days hundreds migrant families released united states border patrol agents thousands hoping chance enter looser policies migrant families force biden confront new border crisis',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations fayette county pennsylvania track covid fayette county pennsylvania',
#        'two hour meeting unclear whether president obama success getting russian counterpart vladimir v putin work end syria rising violence face face obama tries persuade putin syria',
#        'asked prospect leading u military gov walker discussed time boy scouts scott walker eagle scout commander chief',
#        'photos saudi arabia greece india united states september pictures day',
#        'public health officials advising rituals many families cherish state travel large indoor gatherings coronavirus upends thanksgiving many others ignore warnings',
#        'president biden led group counterparts agree plan would cap price russian oil daunting goal risks kremlin restricting supply even counter putin biden tries assemble upside cartel',
#        'president seized reports conservative news outlets bolster case targeted surveillance predecessor political reasons trump tries deflect russia scrutiny citing crooked scheme obama',
#        'solutions economy edge trump sees enemies',
#        'country like world becoming drier wetter era climate change depends live maps tell story two americas one parched one soaked',
#        'science objective analysis need revived years trump medicare medicaid badly need attention',
#        'much proposed border deal would add existing barriers border wall trump built far',
#        'outbreak surges around country testing delays show basic public health challenges country still faces months virus hit ominous sign long lines testing',
#        'future office work deeply uncertain debate sharpened downtowns downtown office district vulnerable even covid',
#        'president trump set course deliver core promise supporters border wall mexico path chose declaring national emergency perilous key takeaways trump decision use national emergency build border wall',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations outagamie county wisconsin track covid outagamie county wisconsin',
#        'division caused israeli prime minister coming speech congress keenly felt among jewish members congress one democratic seems reflect dismay american jews netanyahu visit bringing uninvited problems jewish democrats',
#        'never harder oversee america classrooms driving educators en masse empty classrooms abandoned kids inside america great teacher resignation',
#        'data analysis suggests roughly percent american men gay millions closet many american men gay',
#        'oil companies complain lost revenues government moving forward plans build pipelines canada seeks alternatives transport oil reserves',
#        'sport continues gain popularity companies looking cash pickleball ready prime time',
#        'see latest charts maps coronavirus cases deaths hospitalizations arkansas county arkansas arkansas county arkansas covid case risk tracker',
#        'regulators said people high risk severe covid eligible extra shot setting staggered national booster campaign f authorizes pfizer booster shots older risk americans',
#        'especially women color see shameful trends u maternal health',
#        'also protests france backlash shein friday briefing top u court rules affirmative action',
#        'see full results maps vermont elections vermont election results',
#        'several americans held iran reflect tensions country united states ordeal affects today crisis yesterday hostages today iran',
#        'obama administration ordered travel bans asset freezes seven russian officials including two said mr putin inner circle froze assets companies u expands sanctions adding holdings russians putin financial circle',
#        'term lets politicians distance fact calling sending young americans battle let kick boots ground curb',
#        'flexibility extra person home even days offers significant postpartum benefits new research shows sweden finds simple way improve new mothers health involves fathers',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations gilmer county west virginia track covid gilmer county west virginia',
#        'assumptions much asians americans weigh appears influence perceptions national identity overweight asian americans seen american study finds',
#        'gloria steinem among group female peace activists crossed bus sunday north korea south korea calling end unresolved hostility peace activists cross demilitarized zone separating koreas',
#        'see full results maps georgia special election georgia u senate special election results',
#        'audio complete text president barack obama statement start military action libya full text audio obama statement military action libya',
#        'claims hillary clinton gender make much sense donald trump ridiculous women card comments',
#        'tax restructuring international trade budget policy may offer common ground democrats republicans president obama final two years office chance tax overhaul seen shift power',
#        'see latest charts maps coronavirus cases deaths hospitalizations overland park area johnson county kansas covid case risk tracker',
#        'backlash education standards rage common core',
#        'american conservatives legitimately lay claim ideas edmund burke burke america',
#        'washington metropolitan area transit authority idled metro cars monday one train derailed least three times oct officials said washington metro pulls train cars service derailment',
#        'secretary health human services said letter congress court decision administration would massive damage congress told ruling health law would impact poor',
#        'budget resolution process exposing rifts within republican party congress trouble governing',
#        'republicans latest plan unnecessary cuts social security involves disability fund neverending fight save social security',
#        'iran official news agency said mr rezaian would tried revolutionary court although specify charges iran charges try jason rezaian washington post reporter',
#        'see full results maps california election california election results st congressional district',
#        'andrew keh live blogging world cup qualifying game united states jamaica kingston goal blog television coverage game starts p eastern limited jamaica beats u world cup qualifier',
#        'united states failed reach gold cup final first time since losing jamaica semifinals atlanta jamaica shocks u advances gold cup final',
#        'see full results maps florida election florida election results seventh congressional district',
#        'despite facing turbulence early united states coach jurgen klinsmann part steadied ship still needs get production collection forwards striking comparisons u options forward',
#        'package bills passed bipartisan support versions already senate rare legislative compromise might offing issue attracted growing attention house passes bills aimed stemming human trafficking',
#        'see latest charts maps coronavirus cases deaths hospitalizations napa area napa county california covid case risk tracker',
#        'vote known capitol hill nuclear option would erode little bipartisanship exists senate senate democrats poised block filibusters presidential picks',
#        'see full results maps louisiana election louisiana election results sixth congressional district',
#        'tough new asylum rules alternative pathways apply home designed discourage large numbers migrants traveling border biden administration prepared expected migrant influx',
#        'federal government slowed flow displaced people u trickle achieving bureaucracy executive order apartments stocked toys donated refugees missing',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations stanton county nebraska track covid stanton county nebraska',
#        'joran van der sloot suspect disappearance american teenager serving year prison sentence peru separate murder conviction suspect natalee holloway aruba disappearance extradited u',
#        'see latest charts maps coronavirus cases deaths hospitalizations lamar county georgia lamar county georgia covid case risk tracker',
#        'see full results maps maryland election maryland election results third congressional district',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations jack county texas track covid jack county texas',
#        'hillary clinton aides helped data models experience elections long shifted focus away bubba voters bill clinton evokes past periphery wife campaign',
#        'never many countries including china moved vigor time limit power single industry global tipping point reining tech arrived',
#        'united states twice went ahead let japanese come back shootout americans missed first three tries resilient team soothes nation',
#        'b introducing new social media data analysis software corporate market company long track record tweaking promoting new technology trends widely accepted corporate mainstream b makes social computing strategy smarter',
#        'problems brought us terrible year incubating long time hello cicadas lot happened since',
#        'coronavirus pandemic hurricanes political attitudes might contributed undercount six states mostly south census likely overcounted eight others census miscounted population states review shows',
#        'student leader discusses chose live taiwan sees system surpassing older democracies west future relations beijing q wu er kaixi tiananmen hopes taiwan achievements',
#        'price gallon gas climbed aftermath russia invasion ukraine russia major producer oil u gas prices hit high gallon',
#        'see full results maps florida election florida election results th congressional district',
#        'mitt romney suggests either white house obama campaign officials could behind characterized false accounts paying taxes years romney calls reid tax claims diversion jobs report',
#        'friday sermons across country wide range muslim communities focused similar message solidarity palestinians gaza crisis unites american muslims anger mourning',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations noxubee county mississippi track covid noxubee county mississippi',
#        'fish wildlife service wants allow many birds depicted annual license stamps changing long tradition depicting birds hunted plan change beloved stamp ruffling feathers',
#        'see full results maps wisconsin election wisconsin election results second congressional district',
#        'police acting like constitution rewritten bill rights revised',
#        'see latest charts maps coronavirus cases deaths hospitalizations jefferson county mississippi jefferson county mississippi covid case risk tracker',
#        'many readers recent editorial dissatisfied rented cable boxes already bought others given cable entirely cost cable preposterous readers sound set top boxes',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations mineral county colorado track covid mineral county colorado',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations adair county missouri track covid adair county missouri',
#        'also china russia grow closer u waits news possible donald trump indictment thursday briefing u raises interest rates',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations whitley county indiana track covid whitley county indiana',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations titus county texas track covid titus county texas',
#        'investors expect republican controlled senate remove president trump office according survey rbc capital markets house impeachment vote unlikely sway markets',
#        'see full results maps alabama elections alabama election results',
#        'america passed peak driving end car culture',
#        'see full results maps virginia election virginia election results fifth congressional district',
#        'upward mobility class conscious britain western europe rising american dream opportunity vanishing downton downward',
#        'huge losses many natural disasters little nature natural disaster losses driven building boom america red zones',
#        'infections common deaths high truly new variant year new covid subvariants really change anything',
#        'international herald tribune archives french painting tours united states peace may seen new york',
#        'federal authorities said bank suspected laundering money mexican drug cartels moving cash saudi arabian banks ties terrorists cash moves hsbc inquiry',
#        'inside u government double edged relationship world powerful notorious hacking tool u banned spyware kept trying use',
#        'see full results maps alaska election alaska election results large congressional district',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations williamsburg county south carolina track covid williamsburg county south carolina',
#        'mere labeling change really reduce use antibiotics animal production f really good news',
#        'david herszenhorn times answered readers questions ahead winter olympics twitter q olympic preparations',
#        'international dark sky association awards certifications sites exceptionally high quality night skies including national parks sanctuaries reserves lights new dark sky places top shelf stargazing',
#        'cases deaths dipped vaccinations make scientists hopeful even variants mean coronavirus stay turning corner u covid outlook reaches hopeful point yet',
#        'mind imagines horror edmund pettus bridge president speech past race history president bridge',
#        'u f taboo topic u government anymore long anticipated report released talking u f right',
#        'polling senate races unpredictable largely republican democrat one state may differ politically one another state senate forecasts obvious take look kansas',
#        'first official statement near collision chinese american warships ministry refrained alleging improper conduct american side chinese defense ministry issues statement playing near collision sea',
#        'nan live california state primary election results',
#        'preet bharara u attorney new york southern district investigated arrested convicted astonishing lineup key albany players fighting corruption albany one lawmaker time',
#        'nonprofit marketing group led polio vaccine campaign working million ad blitz counter concerns coming treatments ad council challenge persuade skeptics believe covid vaccines',
#        'outlaw country music star millions like seem found preacher delivers reality spirituality jelly roll heal broken soul america',
#        'employment important factor keeping people criminal justice system keep shutting applicants job hunting criminal record',
#        'universities struggling prevent tightly packed sorority fraternity houses turning virus clusters frats frats greek life stoking virus campuses',
#        'vladimir v putin russian president said united states officials suggested considering unifying efforts regard conflict syria putin u cooperation syria',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations escambia county florida track covid escambia county florida',
#        'hard solve problem barely know going know little america vaccine debacle',
#        'see full results maps pennsylvania election pennsylvania election results th congressional district',
#        'cutting foreign aid would barely make dent deficit would hugely damaging american foreign policy time get stingy',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations kay county oklahoma track covid kay county oklahoma',
#        'americans view politics two camps bickering endlessly fruitlessly unimportant issues real divide america political junkies everyone else',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations walker county georgia track covid walker county georgia',
#        'comes controlling firearms mexico united states feuding neighbors vastly different approach nation gun shop looking north disbelief',
#        'see latest charts maps coronavirus cases deaths hospitalizations portage area kalamazoo county michigan covid case risk tracker',
#        'elite colleges implicit quotas asian americans jews asians smart good',
#        'see latest charts maps coronavirus cases deaths hospitalizations rockford area winnebago county illinois covid case risk tracker',
#        'marzieh hashemi anchor iranian channel press tv accused crime held grand jury testimony done journalist iranian tv detained witness u investigation',
#        'shortages state city personnel especially must work site dire unions helping get people door jobs sit empty public sector unions pitch recruit',
#        'amid nonsense paladins heeding clarion call help treat ebola abroad treated like lepers return ebola hysteria',
#        'cities suburbs schools remain closed teachers unions often saying yet randi weingarten change union leader says get teachers back schools',
#        'something significant planet every time eat peter singer fix diet save planet',
#        'natural resources defense council writes new rules accelerate move toward cleaner electricity sources greater energy efficiency standards power plants',
#        'farewell heartbreaking summer euphoric june look',
#        'paddling pandemic see country water level close personal interesting time two years rivers miles crossing america canoe',
#        'president earlier assertion north korea would produce missile reach united states upended trump north korea options risky',
#        'see latest charts maps coronavirus cases deaths hospitalizations warner robins area peach county georgia covid case risk tracker',
#        'new york california would dominate popular vote electoral college destroy america',
#        'facing primary challenge election house manhattan democrat claims ethics panel biased rangel attacks process led censure',
#        'see latest charts maps coronavirus cases deaths hospitalizations rockingham county new hampshire rockingham county new hampshire covid case risk tracker',
#        'economists warned office jobs united states would soon follow factory jobs moving overseas new research suggests jobs may moving parts country instead white collar job apocalypse happen',
#        'attack building buenos aires killed people showing terrorist organization reach spanned continents u charges hezbollah operative deadly bombing jewish center',
#        'america must secure raw materials clean energy future requires west delusion energy independence',
#        'time think creatively joe biden save roe v wade alone',
#        'million members led xi jinping party encompasses people heights chinese power civil servants everyday life u wants bar members china communist party',
#        'house committee investigating attacks benghazi issued subpoena mr blumenthal emails exchanged mrs clinton sidney blumenthal hillary clinton confidant turns memos libya',
#        'car may towed legitimate reasons parked loading zone instance cases may victim towing company looking earn fees beware car towing companies patrol private parking lots',
#        'reader born confinement site japanese americans writes need keep memory alive internment never happens children japanese american internment',
#        'christian purity movement promoted biblical view abstinence marriage two decades later followers grappling unforeseen aftershocks shamed sex generation evangelicals confronts past retro report',
#        'surprise merging golf rival circuits expected transform sport saudi arabia took pro golf',
#        'see latest charts maps coronavirus cases deaths hospitalizations lansing area ingham county michigan covid case risk tracker',
#        'critics say law gives unfair advantage e commerce companies countries including forced labor issue bipartisan proposals would hit e commerce like fast fashion',
#        'scope implications president immigration move three thoughts amnesty',
#        'biofuel expansion contributed spikes food prices shortage farmland felt keenly guatemala corn based diet land owned handful families biofuel demand grows guatemala hunger pangs',
#        'see latest charts maps coronavirus cases deaths hospitalizations oxford area talladega county alabama covid case risk tracker',
#        'germany prepares lockdown monday briefing',
#        'despite american objections italy set become first group nation participate beijing vast one belt one road infrastructure project forgotten italian port could become chinese gateway europe',
#        'president obama second term begins republican leaders appear ready accede least short term matters like increasing debt limit obama speech leaves g p stark choices',
#        'insurer sold assets repaid government even started making acquisitions yet g still back profitable growth g emerged lost decade yet',
#        'late summer rise covid infections bringing wave conspiracy theories covid cases tick higher conspiracy theorists stoke new fears',
#        'scientists issued new alarm devastating impacts continued burning fossil fuels trump e p keeps propping coal coal killing planet trump loves',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations glades county florida track covid glades county florida',
#        'alex kingsbury thinks could dire consequences continue ignore former president time pay attention trump violent language',
#        'access abortion look like new conservative majority supreme court abortion case tests court',
#        'thousands applicants seeking asylum america claiming persecution homelands fearing life enough kinds cases successful takes get asylum u',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations edwards county illinois track covid edwards county illinois',
#        'men take time work baby born many also filing lawsuits complaints much time take professional setbacks endure return work attitudes shift paid leave dads sue',
#        'foreign ministry warned citizens wanted united states visit nations extradition treaty citing recent arrests russia issues travel warning citizens united states extradition',
#        'presidential race shift higher gear weekend candidates likely ones fan cattle calls woo donors early contest states today politics iowa becomes center campaign world',
#        'hybrid work layoffs higher interest rates leaving lots office space vacant hurting commercial real estate business office buildings still trouble',
#        'programs already plagued delays poor participation designed fully address unemployment primary cause foreclosures jobless little u help foreclosure',
#        'adam jones helped americans beat dominicans saturday reach world baseball classic semifinals second time event four installments u team missing stars finds another hero',
#        'see latest charts maps coronavirus cases deaths hospitalizations henry county georgia henry county georgia covid case risk tracker',
#        'preview games tv weekend involving united states national team players weekend tv guide oct seven reasons stay inside',
#        'working home creates economic winners losers benefit highly skilled employees depress others wages make hard organize upsides remote workers lost pay security others',
#        'program tulsa okla addresses roots incarceration women cheaper better alternative prison',
#        'president obama said would act move resources away interior country face republican refusals overhaul nation immigration laws obama says order action aid immigrants',
#        'april candidates already decided might slip political doldrums year republicans define president obama camp trying remind voters accomplished big things osama bin laden joins u presidential race',
#        'rights away matches involving u world cup qualifying acquired new channel bein sport wednesday channel currently limited distribution u road brazil detours outer space',
#        'top state department official said thursday human rights would feature prominently talks next month president xi jinping china president obama obama set discuss rights issues china',
#        'president biden predicts struggle democracies opponents beijing eager champion side alliance autocracies china wants lead new world order',
#        'feisty tie world cup contender england gave u chance perhaps courage advance tournament call football soccer u claiming',
#        'many offices desolate open plan landscapes dotted individuals staring screens headphones way return office boss go back',
#        'ron haviv hoped images ethnic cleansing bosnia would stop killings recently used evidence commanders charged genocide photography docket evidence',
#        'vaccine also produced long lasting immune responses researchers said booster shots seem unnecessary least johnson johnson vaccine protects delta variant company reports',
#        'chair jerome powell asked every way possible whether economy headed toward recession fed say r word',
#        'stern protestant values continue guide us regardless religious beliefs still puritan years',
#        'lagging behind democrats technologically previous campaigns g p begun using sophisticated techniques target voters g p ads chase voters home go',
#        'scientists yet know well vaccine drug used treat infection working two new trials provide answers monkeypox appears recede risks uncertainties linger',
#        'competition china subtext president obama hosts asean leaders beginning monday rancho mirage calif u drawing southeast asia closer california summit',
#        'slavery cruel institution excused era yes even george washington',
#        'anticipating surge racist hate fueled attacks race officials speaking frankly politically motivated violence f b new approach combating domestic terrorism straight talk',
#        'see latest charts maps coronavirus cases deaths hospitalizations idaho county idaho idaho county idaho covid case risk tracker',
#        'measures targeting billion worth soybeans cars goods latest move countries escalating trade confrontation china strikes back u plans tariffs',
#        'antiquated power lines carry added electricity new solar wind projects really strangling energy transition',
#        'see latest charts maps coronavirus cases deaths hospitalizations gulf shores area baldwin county alabama covid case risk tracker',
#        'go shopping mall get perfume samples free chocolates consider health insurance plans offered things choosing health insurance plan shopping',
#        'house preparing vote unresolved legal controversy whether military may imprison terrorism suspects captured united states soil without trial house consider proposal bar indefinite detention arrests u soil',
#        'country come back democracy says andrei kozyrev former foreign minister optimist view russia',
#        'federal judge took important step toward ending secret donations big spending political groups judge turns light',
#        'glib reductions national essence illuminating america',
#        'flying small plane offers scenes life otherwise hard find intimate view america',
#        'republican national committee appears powerless rein candidates g p save candidates',
#        'united states qualify next round world cup women world cup united states advance round',
#        'downfall one intelligence agent revealed astonishing depth chinese industrial espionage sunday read daring ruse exposed china campaign steal american secrets',
#        'court blocks texas law emergency request groups representing major tech companies like facebook twitter win big tech supreme court',
#        'see latest charts maps coronavirus cases deaths hospitalizations fort smith area sebastian county arkansas covid case risk tracker',
#        'president obama nomination judge merrick b garland set series head spinning political calculations could help determine winner white house race supreme court showdown could shape fall elections',
#        'pentagon called chinese fighter pilot approaching american spy plane dangerous beijing washington division surveillance flights probably remain air encounter likely cause alarm change',
#        'big problem russia china creeping mediocrity biggest threat america america',
#        'real point fireworks overhead tonight let us hear fresh unheard beginning heart nature fourth july high noon year',
#        'neither justin trudeau jacinda ardern save',
#        'first time americans older divorced widowed divorce grows common',
#        'senior u official denying syria claim said russian plane may errantly bombed syrian base russia immediate comment syria blames u base bombing americans blame russia',
#        'united nations mediator syria lakhdar brahimi wrapped second round peace talks saturday without breaking longstanding deadlock setting date third round second round syria talks agreement even negotiate',
#        'white evangelicals tolerate becoming another subculture christian right decline taking america',
#        'stake long term goals like reducing emissions greenhouse gases mr gates said also continued united states leadership industries future bill gates business leaders urge u increase energy research',
#        'students parents try find balance comfortable close college close home boundaries',
#        'new york times reporters providing analysis landmark supreme court decision overturned roe v wade dobbs v jackson decision annotated',
#        'united states become directly involved yemen civil war u became involved war yemen',
#        'see latest charts maps coronavirus cases deaths hospitalizations marshall county kansas marshall county kansas covid case risk tracker',
#        'lessons lewis clark living darkest days longest nights next months going pure hell',
#        'war childhood obesity caused shame leave fat kids alone',
#        'rev dr martin luther king jr wrote edifice produces beggars needs restructuring structural racism really means',
#        'rocket fell near ben gurion airport outside tel aviv federal aviation administration told american carriers halt service hours airlines followed suit airlines suspend flights israel hamas rocket falls near main airport',
#        'savings gasoline would resulted better fuel economy lost consumers paying bill trump fuel efficiency rollbacks hurt drivers',
#        'despite concerns financial condition medicare medicaid americans strongly oppose radical changes critics proposed health care safety net public loves',
#        'times columnists chose tv shows movies books songs capture country see nora ephron explains america',
#        'u spent years preparing coronavirus handle badly america lost lives covid',
#        'partnership new american economy urges congress fix broken visa system visas foreign workers',
#        'best way president obama keep nation track reduce greenhouse gas emissions enact new standards power plants new study suggests new path emissions',
#        'states take managing child support watch money paid parents often disappears state coffers way child support vs deadbeat states',
#        'see latest charts maps coronavirus cases deaths hospitalizations casa grande area pinal county arizona covid case risk tracker',
#        'writer says america failing comparison european countries promoting well populace readers invited respond invitation dialogue challenge america',
#        'fear conspiracy makes terrorism seem threatening crimes fear fear terrorism',
#        'excellence computer chip market puts center battle global technological supremacy pound pound taiwan important place world',
#        'old fashioned hearing russian parliament discussion human rights violations committed united states reminiscent cold war era stung criticism russian lawmakers point human rights abuses u',
#        'th century fad octagonal houses appeal everyone one thing love looking house tight market consider octagon',
#        'another bid formula one race new york announced talk formula one race new york',
#        'international herald tribune archives german minister marine von tirpitz resigns health reasons german admiral resigns',
#        'classic styling plenty power new indian motorcycle line polaris ranks high wow factor first ride reborn indian motorcycles',
#        'italy justice minister protested saying request extradition former c officer robert seldon lady based interpol warrant disregarded without plausible explanations panama former spy returns u',
#        'see latest charts maps coronavirus cases deaths hospitalizations mankato area blue earth county minnesota covid case risk tracker',
#        'without congress political process impeachment investigation happen matter uncovers robert mueller superhero',
#        'see full results maps rhode island election rhode island u senate election results',
#        'chen guangcheng left china last year began day visit taiwan leaving new york amid controversy involving host new york university chinese activist praises taiwan democracy',
#        'return office plans look like post omicron coronavirus briefing back working work',
#        'chad e gutstein entertainment media advisors responds editorial cable giant becomes bigger comcast time warner cable merger',
#        'development enormous consequences define family adulthood general well structure taxation benefits married soon minority',
#        'see latest charts maps coronavirus cases deaths hospitalizations shreveport area caddo parish louisiana covid case risk tracker',
#        'see latest charts maps coronavirus cases deaths hospitalizations covington county alabama covington county alabama covid case risk tracker',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations lincoln county idaho track covid lincoln county idaho',
#        'legal group asked federal appeals court overrule nation spy court allowed collection resume even though data gathering declared illegal c l u asks court stop part n bulk phone data collection',
#        'see faces power behind hollywood justice system big businesses identify black hispanic asian native american multiracial otherwise person color faces power white even u becomes diverse',
#        'federal reserve officials split meet month central bank thinking clearer week fed pressed trump cut rates faces fire matter',
#        'photographers new york times capturing final day voting across america photos election day',
#        'house members attend ethics training sessions teach congress lesson',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations lake county montana track covid lake county montana',
#        'highlights international herald tribune archives united states considers underwriting troops congo u financing africa force',
#        'reading many hateful messages began feel sick literally perils black philosopher',
#        'problems election system extend beyond isolated voting issues locations according study pew charitable trusts lost votes problem ballots long waits flaws widespread study finds',
#        'air travel slowly returning normal thousands homes businesses remained without power powerful storm system moved new england bringing heavy rains floods cleanup begins severe storms tear eastern u',
#        'see latest charts maps coronavirus cases deaths hospitalizations sherman county kansas sherman county kansas covid case risk tracker',
#        'race hangs heavy cases featuring white male defendants accused everything murder insurrection white men trial',
#        'unrelenting march higher continues average price touches new milestone according aaa u gas prices hit new high gallon',
#        'americans win serbia brought joy team lost serbians five years ago semifinal rio games relief redemption u women volleyball team play gold',
# ...
#        'keeping biden campaign night grim one democratic pollster says',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations black hawk county iowa track covid black hawk county iowa',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations san benito county california track covid san benito county california',
#        'see full results maps texas election texas election results th congressional district',
#        'one knows special counsel file report russian interference election whether public see two publishers waiting mueller report already hit sight unseen',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations edgecombe county north carolina track covid edgecombe county north carolina',
#        'passengers could temperature checked subject detailed questioning health officials cautioned draconian measures like travel bans health officials promise extra airport screening ebola',
#        'federal agency sketching expects cities states need local case arises turns lot c c states ponder plans keep ahead zika',
#        'teachers already grappling adrift students political fights mass shooting texas elementary school many wondered much left give pandemic crushed teachers uvalde wonder',
#        'american energy production inched executives fear oil gas prices stay high u oil companies riding europe rescue',
#        'president fantasy u ignore global forces nature donald trump versus jungle',
#        'tesla said sales doubled second quarter ford reported modest increase industry grapples semiconductor shortage sales climb automakers struggle produce enough cars',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations lexington virginia track covid lexington virginia',
#        'reported cases rising fast many states opened early stayed shut longer largely seeing declines coronavirus cases risen since states reopened',
#        'network hit air several prestigious awards never attracted meaningful audience often failing draw viewers prime time short turbulent life al jazeera america',
#        'russian punk protester talks election putin new music video pussy riot nadya trump disqualified',
#        'commute equivalent big bonus many employees future bosses may expect hours exchange remote work economist says battles come benefits working home',
#        'manufacturers cable tv providers say boxes incorporate light sleep mode undergo improvements improve energy efficiency say promises go far enough pledge reform greedy set top boxes',
#        'agreement suspends threat tariffs related spat subsidies airbus boeing turns attention china growing aircraft industry u britain end aircraft subsidy dispute mirroring e u deal',
#        'caterpillar fungus hailed aphrodisiac top pound economic mainstay mountain dwellers nepal becoming scarce demand himalayan viagra fungus heats maybe much',
#        'shootings tennessee virginia arizona south carolina left six dead dozens injured mass shooting philadelphia kills least weekend gun violence',
#        'banana wars spats escalated tariff tariff decades long dispute united states european union bananas explain trade wars',
#        'jen psaki white house press secretary said administration would maintain existing restrictions entry united states europeans others citing concerns spread delta variant white house continue travel bans due delta variant',
#        'u government needs embrace recommendations safer research biology dangerously outpacing policy',
#        'parties struggling find way forward payroll tax democratic republican versions fell short last week new plan payroll taxes expected reid',
#        'estimates exit polls offer initial indication groups voted election night tennessee voter surveys different groups voted',
#        'flying commercial pets becomes increasingly difficult animal owners turning private aviation new airline making bid fur babies dogs cats plane',
#        'see full results maps ohio election ohio election results fifth congressional district',
#        'worker surreptitiously taped mitt romney remarks percent giving account making video man behind percent video comes forward',
#        'obama administration major league baseball quietly working create system would end arduous journey cuban baseball players forced endure open huge untapped fan base deep well talent u cuba trade talks ballplayers named later',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations currituck county north carolina track covid currituck county north carolina',
#        'countries across globe guarantee workers paid family leave tend children elders united states may changing america care care enough',
#        'congress make easier people challenge inclusion list black hole terrorism watch lists',
#        'scout tufankjian traveling world photographing armenian communities large small traditions endure amid diversity following global armenian diaspora',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations catron county new mexico track covid catron county new mexico',
#        'longtime risk communicator says industry drop fierce opposition gmo labels risk communicator says industry embrace labeling genetically modified foods',
#        'china requires citizens corporations conduct espionage state huawei comply spying law',
#        'north carolina passed law perpetuating discrimination lgbt americans mr springsteen canceled upcoming concert greensboro bravo bruce springsteen stand north carolina law',
#        'shiffrin said felt oddly adrift first run finished fourth slalom best event mikaela shiffrin win',
#        'book postponed months errors uncovered earlier year naomi wolf publisher cancels u release outrages',
#        'country quite large numbers deaths actually coming many americans dying right',
#        'c l u attorney chase strangio coordinated strategy behind anti transgender bills introduced year inside republican anti transgender machine',
#        'might sex appeal leonardo dicaprio pretty good artist forget dicaprio another leonardo film star',
#        'special interest spending tilts state courts toward business interests independence top state judges appointed merit selection elected judicial elections bottom line',
#        'also president biden prepares visit northern ireland ireland tuesday briefing china display force around taiwan',
#        'nan live maine state primary election results',
#        'see full results maps ohio election ohio election results th congressional district',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations lafayette county wisconsin track covid lafayette county wisconsin',
#        'conservatives traditional values script used attitudes shift leftward issues including sex marriage marijuana climate change democrats seize social issues attitudes shift',
#        'babies born united states citizens except children foreign diplomats house republicans want change american way birth republicans hate',
#        'given civilian casualties support united states war indefensible america complicit carnage yemen',
#        'large swaths united states still refuse follow simple advice experts coronavirus briefing happened today',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations bledsoe county tennessee track covid bledsoe county tennessee',
#        'pouilly fum lunch parents side pond non joie parenting',
#        'republicans entered final weekend midterm elections clearly holding better hand sour electorate large number undecided voters added measure suspense parties see campaign tilting republicans',
#        'see full results maps new york election new york election results th congressional district',
#        'white house said president obama chancellor angela merkel discussed ways improve cooperation revelations american spying activities jarred relations two countries call obama merkel discuss cooperation intelligence',
#        'officials charleston county c unanimously approved settlement family jamal sutherland died january sheriff deputies used pepper spray tasers county reaches million settlement jailed black man death',
#        'new research shows groups behind math reading disruptions pandemic vulnerable students experienced steepest setbacks pandemic hurt students',
#        'negotiated deal g problems go much deeper one round layoffs trump wrong general motors bailout',
#        'shooting death unarmed black man white police officer north charleston c underscores problems poorly trained police officers lie force necessary walter scott murder',
#        'beijing sure pleased prospect diplomatic process delays possibility war border even talks come nothing talks north korea china approves matter outcome',
#        'thomas schneider retired federal administrative law judge responds editorial tool consumers need harms forced arbitration',
#        'decision capped quarter century legal battle exposed deep divisions role government humans interact nature wolverines require protection u officials rule',
#        'news agency employee went united states study film editing says wants return land chinese dream american life turns one chinese student',
#        'see latest charts maps coronavirus cases deaths hospitalizations bullitt county kentucky bullitt county kentucky covid case risk tracker',
#        'united states overcame early deficit beat france perhaps toughest opponent group u women soccer team beats france',
#        'two appearances journalists president addressed wide range issues including transgender military ban special counselinvestigation trump lot say thursday highlights',
#        'see full results maps kentucky election kentucky election results fifth congressional district',
#        'public perceptions race relations america grown substantially negative aftermath death freddie gray baltimore new york times cbs news poll u race relations',
#        'american troops led united nations forces defend south korea north war ended cease fire agreement korean peninsula still divided korean war photos years truce',
#        'little pomp united states cuba reopened embassies first time since u cuba reopen long closed embassies',
#        'martin bandier signed long term contract oversee sony music publishing division would greatly expand company bid assets emi music publishing approved sony extends contract music executive',
#        'president biden also visited vaccination site washington c ahead remarks finally peace mind biden says addressing start covid vaccinations young children',
#        'disagreement often wish destroy every conversation becomes game lose',
#        'transparency fight misinformation government must say knows covid origins',
#        'asked eight people around world thought american health care go well expensive asked people around world think u health care',
#        'see latest charts maps coronavirus cases deaths hospitalizations pierce county nebraska pierce county nebraska covid case risk tracker',
#        'court ordered desegregation worked white racism made hard accept never busing',
#        'form contentious bill would officially define israel nation state jewish people reserving national rights jews defeated israel narrows democracy',
#        'sonoran desert toad toxins create intense psychedelic experience excuse put one mouth national park service asks visitors please stop licking toads',
#        'organization created wake one world war aimed preventing another celebration accomplishments overshadowed pandemic rising world tensions u n turns celebration muted calamity conflict',
#        'participants say objective build toward time political landscape may shifted enough bill could pass congress senate democrats nighter flags climate change',
#        'asked eight people around world thought go well heartbreaking american health care looks abroad',
#        'president trump claimed eliminated regulations within past year previous administration also promised embrace beautiful clean coal trump american energy policy',
#        'arguing whether racism populism made trump president race class happened',
#        'see latest charts maps coronavirus cases deaths hospitalizations scott county mississippi scott county mississippi covid case risk tracker',
#        'president elect said immigration priority deport three million undocumented immigrants rather million border wall might fence places donald trump appears soften stance immigration abortion',
#        'us liberal conservative sorry matter anymore autumn oscars',
#        'little known customs agreement united states mexico removes major hurdle goods move across border could economic boon south texas trade experts elected officials say laredo quiet symbol closer ties mexico',
#        'see full results maps presidential election washington washington presidential election results',
#        'prepared every american feel behave like police officer firefight good guys guns keep us safe',
#        'representative nancy pelosi california agreed return house minority leader john boehner ohio expected elected speaker house pelosi think walking away job minority leader',
#        'violence continued rage officials said voters overwhelmingly approved new constitution referendum western leaders labeled farce syrians said approve charter battles go',
#        'started popular uprising syrian government four years ago become proto world war nearly dozen countries embroiled two overlapping conflicts untangling overlapping conflicts syrian war',
#        'announcement million people signed plans affordable care act came obama administration braced escalated political battle ahead midterm elections obama claims victory push insurance',
#        'unquantifiable arenas like history arts receding public life replaced technology statistics united states metrics',
#        'less educated white americans problem may tied rosy view past white death rates rising',
#        'recent shifts access abortion suggest democracy women rights go hand hand inverse might true well abortion rights expand u joins handful telling exceptions',
#        'mr obama traveled suburban pittsburgh announce nearly million job training grants separately issued statement attacking house republicans blocking overhaul immigration law obama looks midterm advantage job training immigration',
#        'clinging wiretap claims president draws history pugnacious fighter need prove legitimacy deep sensitivity perception letting go trump small simple task',
#        'republican party left us said founder republican women hillary left republican party made two republican women back hillary clinton',
#        'rare increase driven part people dying drug overdoses suicide alzheimer disease preliminary federal data shows first rise u death rate years surprises experts',
#        'see latest charts maps coronavirus cases deaths hospitalizations middlesex county new jersey middlesex county new jersey covid case risk tracker',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations yamhill county oregon track covid yamhill county oregon',
#        'see full results maps california election california proposition election results repeal ban affirmative action',
#        'president treated worldwide threat assessment presented day scorecard foreign policy something close affront angry trump pushes back naive intelligence officials',
#        'see latest charts maps virus hospitalizations cases deaths tests vaccinations wilkinson county georgia track covid wilkinson county georgia',
#        'nationwide shortage controllers resulted exhausted demoralized work force increasingly prone making dangerous mistakes drunk asleep job air traffic controllers pushed brink',
#        'see latest charts maps coronavirus cases deaths hospitalizations duplin county north carolina duplin county north carolina covid case risk tracker'],
#       dtype='<U239')

# %% [markdown]
# ### Skip Gram

# %%
tokenizer = text.Tokenizer()
tokenizer.fit_on_texts(norm_corpus)

word2id = tokenizer.word_index
id2word = {v:k for k, v in word2id.items()}

vocab_size = len(word2id) + 1 
embed_size = 100

wids = [[word2id[w] for w in text.text_to_word_sequence(doc)] for doc in norm_corpus]
print('Vocabulary Size:', vocab_size)
print('Vocabulary Sample:', list(word2id.items())[:10])
# Out:
# Vocabulary Size: 5463
# Vocabulary Sample: [('county', 1), ('see', 2), ('maps', 3), ('u', 4), ('covid', 5), ('cases', 6), ('election', 7), ('deaths', 8), ('latest', 9), ('charts', 10)]

# %%
# generate skip-grams
skip_grams = [skipgrams(wid, vocabulary_size=vocab_size, window_size=10) for wid in wids]

# view sample skip-grams
pairs, labels = skip_grams[0][0], skip_grams[0][1]
for i in range(10):
    print("({:s} ({:d}), {:s} ({:d})) -> {:d}".format(
          id2word[pairs[i][0]], pairs[i][0], 
          id2word[pairs[i][1]], pairs[i][1], 
          labels[i]))
# Out:
# (nan (552), bubba (2818)) -> 0
# (nan (552), sixth (724)) -> 1
# (house (38), district (29)) -> 1
# (california (47), nan (552)) -> 1
# (primary (371), nan (552)) -> 1
# (house (38), nan (552)) -> 1
# (sixth (724), doublethink (4213)) -> 0
# (election (7), brutality (3899)) -> 0
# (election (7), results (12)) -> 1
# (primary (371), california (47)) -> 1

# %%
# Train neural net with random sample 
from keras.layers import concatenate, Reshape
from keras.layers import Dense
from keras.layers import Embedding
from keras.models import Sequential
from keras.layers import Input, Dot
from keras.models import Model

# %%
word_input = Input(shape=(1,))
word_embedding = Embedding(vocab_size, embed_size,
                           embeddings_initializer="glorot_uniform")(word_input)
word_reshape = Reshape((embed_size,))(word_embedding)
word_model = Model(inputs=word_input, outputs=word_reshape)

# Build context model
context_input = Input(shape=(1,))
context_embedding = Embedding(vocab_size, embed_size,
                              embeddings_initializer="glorot_uniform")(context_input)
context_reshape = Reshape((embed_size,))(context_embedding)
context_model = Model(inputs=context_input, outputs=context_reshape)

# Dot product layer
dot_product = Dot(axes=-1)([word_model.output, context_model.output])

# Dense layer
dense_layer = Dense(1, kernel_initializer="glorot_uniform", activation="sigmoid")(dot_product)

# Combine the models
model = Model(inputs=[word_input, context_input], outputs=dense_layer)

# Compile the model
model.compile(loss="mean_squared_error", optimizer="rmsprop")

# Display model summary
print(model.summary())
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 1)]                  0         []
#
#  input_2 (InputLayer)        [(None, 1)]                  0         []
#
#  embedding_2 (Embedding)     (None, 1, 100)               546300    ['input_1[0][0]']
#
#  embedding_3 (Embedding)     (None, 1, 100)               546300    ['input_2[0][0]']
#
#  reshape_2 (Reshape)         (None, 100)                  0         ['embedding_2[0][0]']
#
#  reshape_3 (Reshape)         (None, 100)                  0         ['embedding_3[0][0]']
#
#  dot (Dot)                   (None, 1)                    0         ['reshape_2[0][0]',
#                                                                      'reshape_3[0][0]']
#
#  dense (Dense)               (None, 1)                    2         ['dot[0][0]']
#
# ==================================================================================================
# Total params: 1092602 (4.17 MB)
# Trainable params: 1092602 (4.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None

# %%
# visualize model structure
from IPython.display import SVG
from keras.utils import plot_model

# Save model summary to a file
model_summary_file = "model_summary.txt"
with open(model_summary_file, 'w') as f:
    model.summary(print_fn=lambda x: f.write(x + '\n'))

# Visualize model structure and save to an image file
plot_model(model, to_file='model_structure.png', show_shapes=True, show_layer_names=False, rankdir='TB')

# %%
for epoch in range(1, 6):
    loss = 0
    for i, elem in enumerate(skip_grams):
        pair_first_elem = np.array(list(zip(*elem[0]))[0], dtype='int32')
        pair_second_elem = np.array(list(zip(*elem[0]))[1], dtype='int32')
        labels = np.array(elem[1], dtype='int32')
        X = [pair_first_elem, pair_second_elem]
        Y = labels
        if i % 10000 == 0:
            print('Processed {} (skip_first, skip_second, relevance) pairs'.format(i))
        loss += model.train_on_batch(X,Y)  

    print('Epoch:', epoch, 'Loss:', loss)
# Out:
# Processed 0 (skip_first, skip_second, relevance) pairs
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1709781183.732484     258 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch: 1 Loss: 246.91745169460773
# Processed 0 (skip_first, skip_second, relevance) pairs
# Epoch: 2 Loss: 233.4477403908968
# Processed 0 (skip_first, skip_second, relevance) pairs
# Epoch: 3 Loss: 226.1217825859785
# Processed 0 (skip_first, skip_second, relevance) pairs
# Epoch: 4 Loss: 218.36101109161973
# Processed 0 (skip_first, skip_second, relevance) pairs
# Epoch: 5 Loss: 210.62013982981443

# %%
# Access layers directly by index
word_input_layer = model.input[0]
word_embedding_layer = model.layers[2]  # Assuming Embedding layer is the third layer in the model

# You can get the weights of the embedding layer as follows
weights = word_embedding_layer.get_weights()[0][1:]

# %%
# view weights
print(weights.shape)
pd.DataFrame(weights, index=id2word.values()).head()
# Out:
# (5462, 100)
#               0         1         2         3         4         5         6   \
# county  0.238985  0.220194 -0.322827 -0.355620  0.176290 -0.178633 -0.337729
# see     0.066303  0.280730 -0.428199 -0.109773  0.207665 -0.173337  0.032032
# maps    0.044534  0.220115 -0.426536 -0.090530  0.215629 -0.240728  0.019075
# u      -0.067984 -0.039947 -0.072943  0.061159  0.105590 -0.120448 -0.043813
# covid   0.259994  0.069328 -0.217372 -0.183622  0.087230 -0.118503 -0.251077
#
#               7         8         9   ...        90        91        92  \
# county -0.534921 -0.142504  0.435694  ... -0.334911 -0.207013  0.400394
# see    -0.464298 -0.253431  0.539552  ... -0.209414 -0.208694  0.158823
# maps   -0.520314 -0.229675  0.507281  ... -0.181325 -0.251032  0.221711
# u      -0.146903 -0.215781  0.193159  ...  0.063628  0.077677  0.066406
# covid  -0.395667 -0.062774  0.363470  ... -0.244865 -0.120814  0.349254
#
#               93        94        95        96        97        98        99
# county -0.215362 -0.466636 -0.167275  0.379549  0.065455 -0.212977 -0.472747
# see    -0.059511 -0.361337 -0.303543  0.289708  0.147237 -0.204380 -0.478805
# maps   -0.062275 -0.385786 -0.327936  0.298213  0.078837 -0.207503 -0.478986
# u       0.017442  0.015075 -0.069139  0.002304  0.056169 -0.131071  0.133617
# covid  -0.217653 -0.306989 -0.074118  0.259696  0.061832 -0.258857 -0.406221
#
# [5 rows x 100 columns]

# %%
# Find closest distance neighbors with clustering
from sklearn.metrics.pairwise import euclidean_distances

distance_matrix = euclidean_distances(weights)
print(distance_matrix.shape)

similar_words = {search_term: [id2word[idx] for idx in distance_matrix[word2id[search_term]-1].argsort()[1:6]+1] 
                   for search_term in ['politics', 'covid', 'united', 'trump', 'russia', 'country', 'war','county']}

similar_words
# Out:
# (5462, 5462)
# {'politics': ['escalated', 'korean', 'advising', 'topics', 'alliance'],
#  'covid': ['cases', 'charts', 'hospitalizations', 'latest', 'deaths'],
#  'united': ['u', 'states', 'president', 'china', 'america'],
#  'trump': ['president', 'world', 'one', 'obama', 'year'],
#  'russia': ['issues', 'children', 'advance', 'gas', 'major'],
#  'country': ['children', 'ukraine', 'including', 'cut', 'across'],
#  'war': ['trade', 'ukraine', 'early', 'era', 'country'],
#  'county': ['deaths', 'hospitalizations', 'cases', 'covid', 'charts']}

# %% [markdown]
# ### Visualize with `t-SNE` which stands for `t-distributed stochastic neighbor embedding` a popular dimensionality reduction technique to visualize higher dimension spaces in lower dimensions (i.e. 2-D)

# %%
from sklearn.manifold import TSNE

words = sum([[k] + v for k, v in similar_words.items()], [])
words_ids = [word2id[w] for w in words]
word_vectors = np.array([weights[idx] for idx in words_ids])
print('Total words:', len(words), '\tWord Embedding shapes:', word_vectors.shape)

tsne = TSNE(n_components=2, random_state=0, n_iter=10000, perplexity=3)
np.set_printoptions(suppress=True)
T = tsne.fit_transform(word_vectors)
labels = words

plt.figure(figsize=(14, 8))
plt.scatter(T[:, 0], T[:, 1], c='steelblue', edgecolors='k')
for label, x, y in zip(labels, T[:, 0], T[:, 1]):
    plt.annotate(label, xy=(x+1, y+1), xytext=(0, 0), textcoords='offset points')
# Out:
# Total words: 48 	Word Embedding shapes: (48, 100)

# %% [markdown]
# ### Scale up with gensim

# %%
from gensim.models import Word2Vec

# tokenize sentences in corpus
wpt = nltk.WordPunctTokenizer()
tokenized_corpus = [wpt.tokenize(document) for document in norm_corpus]

feature_size = 100  # You can adjust the feature size as needed
window_context = 5
min_word_count = 1
sample = 1e-3

w2v_model = Word2Vec(
    sentences=tokenized_corpus,
    vector_size=feature_size,
    window=window_context,
    min_count=min_word_count,
    sample=sample,
    epochs=50  # 'iter' is replaced with 'epochs' in more recent versions
)


# view similar words based on gensim's model
similar_words = {search_term: [item[0] for item in w2v_model.wv.most_similar([search_term], topn=5)]
                  for search_term in ['politics', 'covid', 'united', 'trump', 'russia', 'country', 'war','county']}
similar_words
# Out:
# {'politics': ['opposition', 'cities', 'industry', 'child', 'oil'],
#  'covid': ['personhood', 'macon', 'alabama', 'otter', 'covington'],
#  'united': ['deadbeat', 'ponder', 'metrics', 'september', 'removes'],
#  'trump': ['threatened', 'course', 'philippine', 'endangerment', 'fantasy'],
#  'russia': ['invasion', 'ukraine', 'warning', 'citizens', 'germany'],
#  'country': ['still', 'public', 'guarantee', 'across', 'numbers'],
#  'war': ['reminiscent', 'ukraine', 'cold', 'russia', 'proceed'],
#  'county': ['fillmore', 'scott', 'covington', 'covid', 'lee']}

# %% [markdown]
# ### Comparing, we have some better results but also some more peculiar results (gensim pulls from its library)

# %% [markdown]
# #### Visualize as before with tSNE

# %%
from sklearn.manifold import TSNE

words = sum([[k] + v for k, v in similar_words.items()], [])
wvs = w2v_model.wv[words]

tsne = TSNE(n_components=2, random_state=0, n_iter=10000, perplexity=2)
np.set_printoptions(suppress=True)
T = tsne.fit_transform(wvs)
labels = words

plt.figure(figsize=(14, 8))
plt.scatter(T[:, 0], T[:, 1], c='orange', edgecolors='r')
for label, x, y in zip(labels, T[:, 0], T[:, 1]):
    plt.annotate(label, xy=(x+1, y+1), xytext=(0, 0), textcoords='offset points')

# %% [markdown]
# ### Building a larger scale model based on word2vec

# %%
# Tokenize the corpus
wpt = nltk.WordPunctTokenizer()
tokenized_corpus = [wpt.tokenize(document) for document in norm_corpus]

# Set values for various parameters
feature_size = 10  # Word vector dimensionality  
window_context = 10  # Context window size                                                                                    
min_word_count = 1  # Minimum word count                        
sample = 1e-3  # Downsample setting for frequent words

# Build word2vec model
w2v_model = Word2Vec(
    sentences=tokenized_corpus,
    vector_size=feature_size,
    window=window_context,
    min_count=min_word_count,
    sample=sample,
    epochs=100  # 'iter' is replaced with 'epochs' in more recent versions
)

# Visualize embeddings using t-SNE
from sklearn.manifold import TSNE

words = w2v_model.wv.index_to_key
wvs = w2v_model.wv[words]

tsne = TSNE(n_components=2, random_state=0, n_iter=5000, perplexity=2)
np.set_printoptions(suppress=True)
T = tsne.fit_transform(wvs)

# Plot the embeddings
plt.figure(figsize=(12, 6))
plt.scatter(T[:, 0], T[:, 1], c='orange', edgecolors='r')
for label, x, y in zip(words, T[:, 0], T[:, 1]):
    plt.annotate(label, xy=(x+1, y+1), xytext=(0, 0), textcoords='offset points')

plt.show()

# %% [markdown]
# ### Far too dense to derive any meaning from this cluster

# %%
import numpy as np

def average_word_vectors(words, model, vocabulary, num_features):
    feature_vector = np.zeros((num_features,), dtype="float64")
    nwords = 0.

    for word in words:
        if word in vocabulary:
            nwords = nwords + 1.
            if hasattr(model, 'wv'):
                feature_vector = np.add(feature_vector, model.wv[word])
            else:
                feature_vector = np.add(feature_vector, model[word])

    if nwords:
        feature_vector = np.divide(feature_vector, nwords)

    return feature_vector

def averaged_word_vectorizer(corpus, model, num_features):
    vocabulary = set(model.wv.index_to_key) if hasattr(model, 'wv') else set(model.index_to_key)
    features = [average_word_vectors(tokenized_sentence, model, vocabulary, num_features)
                for tokenized_sentence in corpus]
    return np.array(features)

# get document level embeddings
w2v_feature_array = averaged_word_vectorizer(corpus=tokenized_corpus, model=w2v_model,
                                             num_features=feature_size)
pd.DataFrame(w2v_feature_array)
# Out:
#             0         1         2         3         4         5         6  \
# 0   -2.398697 -3.386747 -2.293845 -1.313337  3.159244 -0.717404  5.226522
# 1    0.263113 -0.534378  2.195645 -1.850362 -0.519598  3.255625  2.919108
# 2    0.832960  0.669908  1.227200  0.616312  0.399200  0.249888  0.912059
# 3   -4.848322  2.859161 -1.409566  1.576694  4.151316  2.861757  3.274658
# 4    1.800231  0.380660  2.048462  0.688577 -1.506779  0.160651  1.278237
# ..        ...       ...       ...       ...       ...       ...       ...
# 995 -2.534403 -2.313742 -1.896470 -1.092950  3.901073  0.885049  4.105087
# 996  2.576112 -2.512909  2.537541 -1.117901 -1.494195 -0.461104  1.796679
# 997 -5.030313  3.023328 -1.503300  1.645337  4.124728  3.000843  3.407332
# 998 -0.232661  0.003030  0.708940  0.198345 -0.123578  0.184452  1.149234
# 999 -6.245420  2.193104 -0.874530  2.242372  3.727281  3.606208  4.185946
#
#             7         8         9
# 0    2.352341 -3.534996 -2.470432
# 1    1.855297 -0.196034  2.125375
# 2    0.503002 -0.964886 -0.824694
# 3   -0.161114 -8.636352  0.954987
# 4   -0.288129 -2.547264  0.473373
# ..        ...       ...       ...
# 995  1.187148 -4.158093 -0.428581
# 996  1.629317 -0.851431 -0.546165
# 997  0.153461 -8.796745  1.179805
# 998 -0.598702 -1.836429 -0.568063
# 999 -0.556889 -6.925641 -0.788417
#
# [1000 rows x 10 columns]

# %% [markdown]
# ### Time to Cluster to form buckets of bins for our categories!

# %%
from sklearn.cluster import AffinityPropagation

ap = AffinityPropagation()
ap.fit(w2v_feature_array)
cluster_labels = ap.labels_
cluster_labels = pd.DataFrame(cluster_labels, columns=['ClusterLabel'])
pd.concat([df, cluster_labels], axis=1)
# Out:
#                                                 Document    Category  \
# 0      see latest charts maps coronavirus cases death...     opinion
# 1      biggest increases come groups past far less li...     opinion
# 2      miguel cardona education secretary said reopen...     opinion
# 3      mohamed morsi egypt first democratically elect...      sports
# 4      see full results maps district columbia electi...      sports
# ...                                                  ...         ...
# 25505  abdicated parental rights duties new societal ...      health
# 25506  overcame desperation felt stepping congress st...  the upshot
# 25507  former n f l wide receiver joined premier lacr...       world
# 25508  placing tracking devices netbooks discarded ce...     opinion
# 25509  sales alternative fuel vehicle fallen along ga...     opinion
#
#        ClusterLabel
# 0               0.0
# 1              17.0
# 2              27.0
# 3               6.0
# 4              41.0
# ...             ...
# 25505           NaN
# 25506           NaN
# 25507           NaN
# 25508           NaN
# 25509           NaN
#
# [25510 rows x 3 columns]

# %% [markdown]
# ### Wow! That's a lot of ClusterLabels...which makes sense we have over 25k unique rows!!!

# %% [markdown]
# #### Use PCA to reduce dimensionality!

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2, random_state=0)
pcs = pca.fit_transform(w2v_feature_array)
labels = ap.labels_
categories = list(df['Category'])
plt.figure(figsize=(8, 6))

for i in range(len(labels)):
    label = labels[i]
    color = 'orange' if label == 0 else 'yellow' if label == 1 else 'green'
    annotation_label = categories[i]
    x, y = pcs[i]
    plt.scatter(x, y, c=color, edgecolors='k')
    plt.annotate(annotation_label, xy=(x+1e-4, y+1e-3), xytext=(0, 0), textcoords='offset points')
